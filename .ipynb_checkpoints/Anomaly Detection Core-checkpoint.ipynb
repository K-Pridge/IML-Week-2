# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score

# %%
from sklearn.datasets import make_blobs
# Create dataset with 3 centers
X_, y_ = make_blobs(n_samples=300, centers=3, random_state=42)
X = pd.read_csv('Data/credit_card.csv')
X.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10  ...       V20       V21       V22       V23  \
# 0  0.098698  0.363787  0.090794  ...  0.251412 -0.018307  0.277838 -0.110474
# 1  0.085102 -0.255425 -0.166974  ... -0.069083 -0.225775 -0.638672  0.101288
# 2  0.247676 -1.514654  0.207643  ...  0.524980  0.247998  0.771679  0.909412
# 3  0.377436 -1.387024 -0.054952  ... -0.208038 -0.108300  0.005274 -0.190321
# 4 -0.270533  0.817739  0.753074  ...  0.408542 -0.009431  0.798278 -0.137458
#
#         V24       V25       V26       V27       V28  Amount
# 0  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69
# 2 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50
# 4  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99
#
# [5 rows x 29 columns]

# %%
X = StandardScaler().fit_transform(X)
X
# Out:
# array([[-7.26092283e-01, -2.70865033e-01,  1.38997989e+00, ...,
#          3.12928904e-01, -9.00094641e-02,  4.59472255e-01],
#        [ 9.49810332e-01, -1.30202285e-02, -6.47336365e-01, ...,
#         -3.90875344e-02,  4.35004752e-02, -3.33835128e-01],
#        [-7.25137922e-01, -1.23503469e+00,  7.33929373e-01, ...,
#         -1.53600835e-01, -2.34421812e-01,  1.69610959e+00],
#        ...,
#        [-1.41477653e+00, -6.18349768e-01,  1.99225183e+00, ...,
#          9.27441474e-01, -6.75591305e-01, -1.91781652e-01],
#        [ 2.43405682e-01, -1.43846662e-01, -4.12310497e-01, ...,
#          3.33142352e-01,  1.55375219e-01, -1.90066147e-02],
#        [ 9.83163180e-01, -7.39864589e-01,  5.82407735e-02, ...,
#          4.98952925e-04,  1.00780712e-02, -2.02634084e-01]])

# %%
from sklearn.cluster import KMeans
# Apply K-Means algorithm
kmeans = KMeans(n_clusters=3, n_init=10, random_state = 42)
kmeans.fit(X)
# Out:
# KMeans(n_clusters=3, n_init=10, random_state=42)

# %%
# Making a dataframe copy of X for saving clusters 
df = X.copy()
df['cluster'] = kmeans.predict(X)
df.head()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[15], line 3
#       1 # Making a dataframe copy of X for saving clusters
#       2 df = X.copy()
# ----> 3 df['cluster'] = kmeans.predict(X)
#       4 df.head()
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
